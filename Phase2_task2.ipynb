# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
train_df=pd.read_csv('/content/sample_data/train_dataset.csv')
test_df=pd.read_csv('/content/sample_data/test_dataset.csv')

# %%
train_df
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
test_df
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
xtrain=train_df["x"]
xtest=test_df["x"]
xtrain
# Out:
# 0      24.0
# 1      50.0
# 2      15.0
# 3      38.0
# 4      87.0
#        ...
# 695    58.0
# 696    93.0
# 697    82.0
# 698    66.0
# 699    97.0
# Name: x, Length: 700, dtype: float64

# %%
xtest
# Out:
# 0      77
# 1      21
# 2      22
# 3      20
# 4      36
#        ..
# 295    71
# 296    46
# 297    55
# 298    62
# 299    47
# Name: x, Length: 300, dtype: int64

# %%
ytrain=train_df["y"]
ytest=test_df["y"]
ytrain
# Out:
# 0      21.549452
# 1      47.464463
# 2      17.218656
# 3      36.586398
# 4      87.288984
#          ...
# 695    58.595006
# 696    94.625094
# 697    88.603770
# 698    63.648685
# 699    94.975266
# Name: y, Length: 700, dtype: float64

# %%
ytest
# Out:
# 0      79.775152
# 1      23.177279
# 2      25.609262
# 3      17.857388
# 4      41.849864
#          ...
# 295    68.545888
# 296    47.334876
# 297    54.090637
# 298    63.297171
# 299    52.459467
# Name: y, Length: 300, dtype: float64

# %%
train_df=train_df.fillna(train_df["y"].mean())

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(train_df[["x"]],train_df[["y"]])
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
plt.scatter(train_df[["y"]],train_df[["y"]], marker='*')

# %%
ypredict=0
ypredict=reg.predict(test_df[["x"]])
ypredict
# Out:
# array([[50.95653945],
#        [48.37030441],
#        [48.41648718],
#        [48.32412164],
#        [49.06304594],
#        [48.0932078 ],
#        [50.26379792],
#        [51.78782928],
#        [48.32412164],
#        [47.63138011],
#        [47.58519734],
#        [48.27793887],
#        [51.83401205],
#        [50.26379792],
#        [49.06304594],
#        [48.0932078 ],
#        [50.40234623],
#        [48.04702503],
#        [51.41836714],
#        [50.5870773 ],
#        [51.51073267],
#        [49.75578747],
#        [51.51073267],
#        [48.64740102],
#        [51.88019482],
#        [50.07906685],
#        [51.04890499],
#        [48.37030441],
#        [51.69546375],
#        [48.64740102],
#        [51.97256036],
#        [48.8321321 ],
#        [48.92449763],
#        [51.09508776],
#        [48.69358379],
#        [49.57105639],
#        [49.848153  ],
#        [50.5870773 ],
#        [48.69358379],
#        [48.92449763],
#        [51.60309821],
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(test_df[["y"]],test_df[["y"]], marker='*')

# %%
import matplotlib.pyplot as plt
plt.scatter(train_df[["y"]],train_df[["y"]], marker='*')
